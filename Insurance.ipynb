# %%
import pandas as pd

# %%
df=pd.read_csv('insurance.csv')
df
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %%
from pycaret.regression import *
experiment1= setup(data = df, target = 'charges')
# Out:
# <style  type="text/css" >
#     #T_4dfe792b_16fc_11ec_b60d_5c3a45244752row42_col1 {
#             background-color:  lightgreen;
#         }</style><table id="T_4dfe792b_16fc_11ec_b60d_5c3a45244752" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Description</th>        <th class="col_heading level0 col1" >Value</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_4dfe792b_16fc_11ec_b60d_5c3a45244752level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_4dfe792b_16fc_11ec_b60d_5c3a45244752row0_col0" class="data row0 col0" >session_id</td>
#                         <td id="T_4dfe792b_16fc_11ec_b60d_5c3a45244752row0_col1" class="data row0 col1" >8237</td>
#             </tr>
#             <tr>
#                         <th id="T_4dfe792b_16fc_11ec_b60d_5c3a45244752level0_row1" class="row_heading level0 row1" >1</th>
# ...

# %%
lr1 = create_model('lr')
# Out:
# <style  type="text/css" >
#     #T_50e75d4e_16fc_11ec_9e08_5c3a45244752row10_col0 {
#             background:  yellow;
#         }    #T_50e75d4e_16fc_11ec_9e08_5c3a45244752row10_col1 {
#             background:  yellow;
#         }    #T_50e75d4e_16fc_11ec_9e08_5c3a45244752row10_col2 {
#             background:  yellow;
#         }    #T_50e75d4e_16fc_11ec_9e08_5c3a45244752row10_col3 {
#             background:  yellow;
#         }    #T_50e75d4e_16fc_11ec_9e08_5c3a45244752row10_col4 {
#             background:  yellow;
#         }    #T_50e75d4e_16fc_11ec_9e08_5c3a45244752row10_col5 {
#             background:  yellow;
# ...

# %%
plot_model(lr1, plot = 'residuals')

# %%
experiment2 = setup(data=df, target = 'charges', session_id = 123,
           normalize = True,
           polynomial_features = True, trigonometry_features = True,
           feature_interaction=True, 
           bin_numeric_features= ['age', 'bmi'])
# Out:
# <style  type="text/css" >
#     #T_58272133_16fc_11ec_8754_5c3a45244752row27_col1 {
#             background-color:  lightgreen;
#         }    #T_58272133_16fc_11ec_8754_5c3a45244752row37_col1 {
#             background-color:  lightgreen;
#         }    #T_58272133_16fc_11ec_8754_5c3a45244752row42_col1 {
#             background-color:  lightgreen;
#         }    #T_58272133_16fc_11ec_8754_5c3a45244752row45_col1 {
#             background-color:  lightgreen;
#         }    #T_58272133_16fc_11ec_8754_5c3a45244752row47_col1 {
#             background-color:  lightgreen;
#         }    #T_58272133_16fc_11ec_8754_5c3a45244752row53_col1 {
#             background-color:  lightgreen;
#         }</style><table id="T_58272133_16fc_11ec_8754_5c3a45244752" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Description</th>        <th class="col_heading level0 col1" >Value</th>    </tr></thead><tbody>
#                 <tr>
# ...

# %%
lr2 = create_model('lr')
# Out:
# <style  type="text/css" >
#     #T_584e8df9_16fc_11ec_acc2_5c3a45244752row10_col0 {
#             background:  yellow;
#         }    #T_584e8df9_16fc_11ec_acc2_5c3a45244752row10_col1 {
#             background:  yellow;
#         }    #T_584e8df9_16fc_11ec_acc2_5c3a45244752row10_col2 {
#             background:  yellow;
#         }    #T_584e8df9_16fc_11ec_acc2_5c3a45244752row10_col3 {
#             background:  yellow;
#         }    #T_584e8df9_16fc_11ec_acc2_5c3a45244752row10_col4 {
#             background:  yellow;
#         }    #T_584e8df9_16fc_11ec_acc2_5c3a45244752row10_col5 {
#             background:  yellow;
# ...

# %%
plot_model(lr2, plot = 'residuals')

# %%
save_model(lr2, model_name = 'C:/Users/Snehal/Desktop/ds/deployment_28042020')
# Out:
# Transformation Pipeline and Model Successfully Saved
# (Pipeline(memory=None,
#           steps=[('dtypes',
#                   DataTypes_Auto_infer(categorical_features=[],
#                                        display_types=True, features_todrop=[],
#                                        id_columns=[], ml_usecase='regression',
#                                        numerical_features=[], target='charges',
#                                        time_features=[])),
#                  ('imputer',
#                   Simple_Imputer(categorical_strategy='not_available',
#                                  fill_value_categorical=None,
#                                  fill_value_numerical=None,
#                                  numeric_strategy...
#                  ('feature_select', 'passthrough'), ('fix_multi', 'passthrough'),
#                  ('dfs',
#                   DFS_Classic(interactions=['multiply'], ml_usecase='regression',
# ...
